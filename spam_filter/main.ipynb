# %% [markdown]
# ### Проект 1 [Спам-фильтр]

# %% [markdown]
# Вам предоставляется набор данных SMS-сообщений ```spam.csv```, классифицированных как спам и не спам.
# **Цель:** построить модель, которая будет классифицировать сообщение как спам / не спам на основе наивного байесовского алгоритма.
#
# Пожалуйста, проверьте модули ```dataset.py``` и ```model.py```.
#
# Точность классификации сообщений должна быть более 95% как для validation, так и для test набора данных.

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('spam.csv', encoding='cp1251')
data.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], inplace=True)
data.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
#import library Datast
from dataset import Dataset
dataset = Dataset(data['v1'], data['v2'])

# %%
#print dataset
print(dataset)
# Out:
# [array([0, 0, 1, ..., 0, 0, 0]), array(['go until jurong point crazy available only in bugis n great world la e buffet cine there got amore wat',
#        'ok lar joking wif u oni',
#        'free entry in 2 a wkly comp to win fa cup final tkts 21st may 2005 text fa to 87121 to receive entry question std txt rate t c s apply 08452810075over18 s',
#        ..., 'pity was in mood for that so any other suggestions',
#        'the guy did some bitching but i acted like i d be interested in buying something else next week and he gave it to us for free',
#        'rofl its true to its name'], dtype='<U907')]

# %%
#splitting dataset
dataset.split_dataset()

# %%
#importing model "Model" which we created before
from model import Model
m = Model()
m.fit(dataset)

# %%
m.vocab
# Out:
# {'yeah': 64,
#  'do': 335,
#  'don': 137,
#  't': 393,
#  'stand': 5,
#  'to': 1808,
#  'close': 16,
#  'tho': 15,
#  'you': 1807,
#  'll': 235,
#  'catch': 7,
#  'something': 55,
#  'sleeping': 13,
#  'nt': 13,
#  'feeling': 16,
#  'well': 91,
#  'come': 178,
#  'aftr': 5,
#  'lt': 248,
#  'decimal': 20,
#  'gt': 249,
#  'now': 404,
#  'i': 2416,
#  'm': 352,
#  'cleaning': 4,
#  'the': 1086,
#  'house': 30,
#  'almost': 12,
#  'there': 188,
#  'see': 136,
#  'u': 937,
#  'in': 726,
#  'a': 1171,
#  'sec': 4,
#  'probably': 26,
#  'earlier': 14,
#  'than': 31,
#  'that': 479,
#  'hello': 45,
#  'my': 578,
#  'love': 165,
#  'what': 237,
#  'are': 368,
#  'doing': 73,
#  'did': 103,
#  'get': 311,
#  'interview': 4,
#  'today': 129,
#  'happy': 83,
#  'being': 36,
#  'good': 198,
#  'boy': 26,
#  'think': 105,
#  'of': 495,
#  'me': 621,
#  'missing': 17,
#  '2mro': 1,
#  'am': 174,
#  'not': 325,
#  'coming': 39,
#  'gym': 9,
#  'machan': 3,
#  'goodnight': 7,
#  'free': 220,
#  'ring': 15,
#  'tone': 52,
#  'just': 308,
#  'text': 157,
#  'polys': 8,
#  '87131': 4,
#  'then': 205,
#  'every': 64,
#  'week': 98,
#  'new': 105,
#  '0870737910216yrs': 1,
#  'only': 167,
#  '1': 133,
#  '50': 48,
#  'wk': 30,
#  'camera': 30,
#  'awarded': 29,
#  'sipix': 6,
#  'digital': 6,
#  'call': 474,
#  '09061221066': 4,
#  'fromm': 4,
#  'landline': 29,
#  'delivery': 18,
#  'within': 11,
#  '28': 6,
#  'days': 38,
#  'tbs': 1,
#  'persolvo': 1,
#  'been': 104,
#  'chasing': 3,
#  'us': 55,
#  'since': 23,
#  'sept': 4,
#  'for': 563,
#  '38': 1,
#  'definitely': 6,
#  'paying': 8,
#  'thanks': 70,
#  'your': 542,
#  'information': 9,
#  'we': 339,
#  'will': 311,
#  'ignore': 5,
#  'them': 66,
#  'kath': 1,
#  'manchester': 1,
#  'small': 8,
#  'problem': 31,
#  'auction': 12,
#  'punj': 1,
#  'asking': 8,
#  'tiwary': 2,
#  'know': 218,
#  'someone': 52,
#  'who': 98,
#  'fancies': 1,
#  '09058097218': 1,
#  'find': 67,
#  'out': 210,
#  'pobox': 12,
#  '6': 39,
#  'ls15hb': 2,
#  '150p': 60,
#  'still': 129,
#  'chance': 27,
#  'if': 322,
#  'search': 13,
#  'hard': 15,
#  'it': 605,
#  'let': 65,
#  'have': 472,
#  'try': 39,
#  'happened': 13,
#  'here': 103,
#  'while': 21,
#  'were': 50,
#  'adventuring': 1,
#  'eat': 33,
#  'at': 313,
#  'old': 13,
#  'airport': 5,
#  'road': 7,
#  'but': 357,
#  '630': 2,
#  'oredi': 8,
#  'got': 191,
#  'lot': 28,
#  'pple': 4,
#  'sent': 56,
#  'ur': 312,
#  'email': 17,
#  'id': 14,
#  'soon': 52,
#  'hey': 82,
#  'want': 159,
#  'go': 234,
#  'yogasana': 4,
#  'coz': 18,
#  'end': 34,
#  'cine': 7,
#  'can': 381,
#  'bathe': 6,
#  'and': 784,
#  'hav': 23,
#  'steam': 2,
#  'bath': 9,
#  'two': 25,
#  'fundamentals': 1,
#  'cool': 36,
#  'life': 61,
#  'walk': 14,
#  'parents': 9,
#  'kidz': 1,
#  'friends': 42,
#  'n': 112,
#  'colleagues': 3,
#  'all': 220,
#  'screaming': 2,
#  'surprise': 8,
#  'was': 178,
#  'waiting': 40,
#  'on': 423,
#  'sofa': 4,
#  'naked': 4,
#  'sorry': 124,
#  'missed': 18,
#  's': 477,
#  'talk': 40,
#  'when': 243,
#  'time': 170,
#  '07090201529': 1,
#  'ok': 232,
#  'finishing': 1,
#  'dun': 48,
#  'say': 78,
#  'so': 375,
#  'early': 28,
#  'hor': 2,
#  'c': 98,
#  'already': 71,
#  'down': 46,
#  'gandhipuram': 1,
#  'cross': 3,
#  'cut': 11,
#  'right': 76,
#  'side': 10,
#  'street': 9,
#  'turn': 4,
#  'first': 54,
#  'hi': 106,
#  'dear': 92,
#  'its': 175,
#  'urgnt': 5,
#  'whats': 10,
#  'work': 87,
#  'or': 343,
#  'any': 114,
#  'other': 50,
#  'least': 11,
#  'tell': 107,
#  'wating': 2,
#  'reply': 114,
#  'pls': 106,
#  'help': 51,
#  'ashley': 2,
#  'cant': 54,
#  'her': 116,
#  'number': 73,
#  'oh': 92,
#  'umma': 5,
#  'she': 134,
#  'anything': 60,
#  'dont': 120,
#  'studying': 9,
#  'stress': 3,
#  'l8r': 4,
#  'stupid': 10,
#  'possible': 6,
#  'better': 35,
#  'ask': 67,
#  'sell': 6,
#  'wen': 19,
#  'finish': 36,
#  'wrk': 3,
#  'fancy': 9,
#  'meetin': 3,
#  'up': 257,
#  'wiv': 7,
#  'tonite': 8,
#  'as': 149,
#  'need': 137,
#  'break': 13,
#  'from': 227,
#  'dabooks': 1,
#  '4': 259,
#  'hrs': 5,
#  'last': 64,
#  'nite': 20,
#  '2': 412,
#  'no': 295,
#  'movie': 17,
#  'is': 725,
#  'leave': 47,
#  'an': 95,
#  'hourish': 1,
#  'taj': 1,
#  'mahal': 1,
#  'symbol': 3,
#  'lesser': 1,
#  'known': 1,
#  'facts': 1,
#  'mumtaz': 4,
#  'shahjahan': 2,
#  '4th': 5,
#  'wife': 20,
#  'his': 51,
#  '7': 36,
#  'wifes': 1,
#  'killed': 2,
#  'husband': 2,
#  'marry': 6,
#  '3': 81,
#  'died': 4,
#  'th': 9,
#  'he': 195,
#  'married': 6,
#  'sister': 13,
#  'question': 18,
#  'arises': 1,
#  'where': 88,
#  'hell': 6,
#  'great': 88,
#  'hari': 1,
#  'k': 123,
#  'give': 88,
#  'treat': 13,
#  'chinese': 4,
#  'food': 17,
#  'way': 88,
#  'fat': 5,
#  're': 98,
#  'lipo': 1,
#  'complain': 1,
#  'num': 6,
#  'bettr': 1,
#  'directly': 5,
#  'bsnl': 1,
#  'offc': 1,
#  'nd': 3,
#  'apply': 22,
#  'uhhhhrmm': 1,
#  'isnt': 6,
#  'having': 31,
#  'tb': 3,
#  'test': 19,
#  'bad': 28,
#  'youre': 2,
#  'sick': 9,
#  'goodmorning': 11,
#  'late': 47,
#  '2hrs': 1,
#  'because': 30,
#  'back': 133,
#  'pain': 21,
#  'remember': 24,
#  'day': 181,
#  'theory': 3,
#  'going': 133,
#  'book': 17,
#  '21': 3,
#  'may': 30,
#  'thought': 37,
#  'wanna': 27,
#  'with': 314,
#  'jiayin': 2,
#  'bit': 37,
#  'smile': 36,
#  'hppnss': 2,
#  'drop': 17,
#  'tear': 5,
#  'sorrow': 2,
#  'part': 24,
#  'heart': 40,
#  'like': 204,
#  'mine': 17,
#  'wil': 15,
#  'care': 57,
#  'forevr': 2,
#  'goodfriend': 2,
#  'one': 137,
#  'saying': 16,
#  'clearly': 2,
#  'thk': 44,
#  '530': 3,
#  'lor': 142,
#  'dunno': 25,
#  'tickets': 5,
#  'wat': 83,
#  'hear': 24,
#  'philosophy': 3,
#  'happen': 17,
#  'they': 114,
#  'talking': 10,
#  'thats': 35,
#  'de': 13,
#  'wont': 29,
#  'read': 9,
#  'exams': 5,
#  'gr8': 18,
#  'message': 78,
#  'r': 129,
#  'leaving': 15,
#  'congrats': 16,
#  'school': 20,
#  'plans': 8,
#  'belive': 2,
#  'home': 123,
#  'yes': 76,
#  'office': 23,
#  'lap': 1,
#  'room': 29,
#  'few': 39,
#  'didnt': 25,
#  'shut': 3,
#  'mah': 10,
#  'b': 64,
#  'pick': 60,
#  'tomorrow': 76,
#  'gei': 1,
#  'happend': 3,
#  'tron': 1,
#  'maybe': 25,
#  'ill': 30,
#  'dl': 1,
#  '3d': 4,
#  'hurry': 5,
#  've': 78,
#  'weed': 8,
#  'deficient': 1,
#  'three': 4,
#  'ringtone': 25,
#  'order': 20,
#  'reference': 6,
#  'x29': 1,
#  'mobile': 116,
#  'be': 307,
#  'charged': 11,
#  'should': 80,
#  'arrive': 6,
#  'please': 118,
#  'customer': 41,
#  'services': 12,
#  '09065989180': 1,
#  'amanda': 1,
#  'regard': 1,
#  'renewing': 1,
#  'upgrading': 1,
#  'current': 5,
#  'handset': 5,
#  'charge': 18,
#  'offer': 26,
#  'ends': 9,
#  'tel': 14,
#  '0845': 3,
#  '021': 2,
#  '3680': 2,
#  'subject': 1,
#  'hungry': 12,
#  'gay': 7,
#  'guys': 30,
#  '08718730555': 1,
#  '10p': 20,
#  'min': 56,
#  'stop': 123,
#  'texts': 18,
#  '08712460324': 7,
#  'romcapspam': 1,
#  'everyone': 16,
#  'around': 51,
#  'responding': 2,
#  'presence': 1,
#  'warm': 7,
#  'outgoing': 1,
#  'bringing': 3,
#  'real': 32,
#  'breath': 2,
#  'sunshine': 9,
#  'buy': 56,
#  'space': 6,
#  'invaders': 1,
#  'win': 55,
#  'orig': 1,
#  'arcade': 4,
#  'game': 18,
#  'console': 1,
#  'press': 10,
#  '0': 2,
#  'games': 16,
#  'std': 5,
#  'wap': 7,
#  'o2': 4,
#  'co': 47,
#  'uk': 64,
#  'terms': 7,
#  'settings': 2,
#  'purchase': 3,
#  'again': 50,
#  'ryan': 1,
#  'fun': 22,
#  'practicing': 2,
#  'making': 18,
#  'babies': 2,
#  'spjanuary': 1,
#  'male': 3,
#  'sale': 7,
#  'hot': 20,
#  'chat': 50,
#  'cheaper': 5,
#  '08709222922': 2,
#  'national': 18,
#  'rate': 25,
#  '5p': 3,
#  'cheap': 8,
#  '8p': 2,
#  'peak': 2,
#  'weird': 4,
#  'even': 52,
#  'supposed': 12,
#  'happening': 7,
#  'idea': 8,
#  'sure': 58,
#  'pub': 15,
#  '25p': 6,
#  'alfie': 3,
#  'moon': 7,
#  'children': 8,
#  'song': 12,
#  'mob': 19,
#  'm8s': 3,
#  'txt': 133,
#  'charity': 9,
#  '8007': 19,
#  'nokias': 3,
#  'poly': 16,
#  'zed': 6,
#  '08701417012': 3,
#  'profit': 4,
#  'face': 26,
#  'choices': 1,
#  'toss': 1,
#  'coin': 2,
#  'becoz': 4,
#  'settle': 3,
#  'air': 5,
#  'hoping': 9,
#  'gudni8': 1,
#  'about': 130,
#  'this': 275,
#  'mean': 17,
#  'king': 8,
#  'havin': 2,
#  'credit': 12,
#  'goin2bed': 1,
#  'night': 92,
#  'sweet': 29,
#  'only1more': 1,
#  'sleep': 47,
#  'phones': 12,
#  'linerental': 3,
#  '49': 1,
#  'month': 36,
#  '750': 13,
#  'ntwk': 3,
#  'mins': 37,
#  'price': 18,
#  'bundle': 1,
#  'deals': 1,
#  'also': 58,
#  'avble': 1,
#  '08001950382': 2,
#  'call2optout': 9,
#  'j': 6,
#  'mf': 1,
#  'urgent': 57,
#  '09066350750': 2,
#  'complimentary': 11,
#  'ibiza': 4,
#  'holiday': 39,
#  '10': 32,
#  '000': 22,
#  'cash': 73,
#  'await': 16,
#  'collection': 23,
#  'sae': 18,
#  'cs': 39,
#  'po': 31,
#  'box': 33,
#  '434': 5,
#  'sk3': 3,
#  '8wp': 3,
#  '150': 13,
#  'ppm': 4,
#  '18': 43,
#  'how': 252,
#  'teach': 5,
#  'seen': 11,
#  'holby': 1,
#  'congratulations': 12,
#  'claim': 84,
#  'vip': 4,
#  'row': 16,
#  'blu': 2,
#  'concert': 3,
#  'november': 1,
#  'gift': 18,
#  'guaranteed': 43,
#  '09061104276': 1,
#  'ts': 8,
#  'www': 76,
#  'smsco': 2,
#  'net': 20,
#  'cost': 32,
#  '75max': 1,
#  'wan': 43,
#  'too': 94,
#  'lei': 19,
#  'outside': 14,
#  'wun': 5,
#  'neva': 14,
#  'mind': 23,
#  'haven': 21,
#  'explicitly': 1,
#  'told': 47,
#  'nora': 1,
#  'gonna': 48,
#  'bother': 5,
#  '88800': 1,
#  '89034': 1,
#  'premium': 2,
#  'phone': 90,
#  '08718711108': 1,
#  'use': 42,
#  'ni8': 10,
#  'much': 98,
#  'getting': 42,
#  'little': 25,
#  'difficult': 10,
#  'simple': 17,
#  'enter': 12,
#  'place': 48,
#  'came': 19,
#  'look': 24,
#  'flat': 4,
#  'seems': 9,
#  '50s': 1,
#  'away': 20,
#  'alot': 1,
#  'woman': 4,
#  '30': 9,
#  'uncles': 4,
#  'atlanta': 3,
#  'wish': 37,
#  'semester': 10,
#  'town': 24,
#  'meet': 69,
#  'exciting': 5,
#  'adult': 5,
#  'singles': 5,
#  '86688': 17,
#  'msg': 96,
#  'later': 105,
#  'tonight': 48,
#  'mate': 11,
#  'catching': 3,
#  'some': 102,
#  'by': 141,
#  'really': 69,
#  'dudette': 1,
#  'mesages': 2,
#  'y': 30,
#  'hurts': 6,
#  'take': 115,
#  'exam': 9,
#  'march': 11,
#  'sppok': 1,
#  'halloween': 3,
#  'nokia': 52,
#  'logo': 7,
#  'pic': 17,
#  'plus': 21,
#  'eerie': 5,
#  'card': 15,
#  'spook': 5,
#  'todays': 18,
#  'vodafone': 5,
#  'numbers': 11,
#  'ending': 9,
#  '0089': 1,
#  'four': 2,
#  'digits': 1,
#  'selected': 24,
#  'received': 4,
#  '350': 15,
#  'award': 27,
#  'matches': 8,
#  '09063442151': 1,
#  'lol': 60,
#  'drunkard': 1,
#  'hair': 21,
#  'd': 111,
#  'moment': 8,
#  'wats': 6,
#  'plan': 27,
#  'searching': 5,
#  'words': 20,
#  'thank': 24,
#  'breather': 1,
#  'promise': 8,
#  'granted': 1,
#  'fulfil': 1,
#  'wonderful': 14,
#  'blessing': 1,
#  'times': 20,
#  'car': 33,
#  'keys': 3,
#  'purse': 1,
#  'neighbors': 1,
#  'nothing': 32,
#  'smsing': 1,
#  'xy': 8,
#  'da': 110,
#  'person': 38,
#  'sort': 7,
#  'bring': 23,
#  'along': 4,
#  'our': 118,
#  'next': 51,
#  'meeting': 35,
#  'movies': 5,
#  'laptop': 5,
#  'working': 23,
#  'eyes': 8,
#  'more': 84,
#  'quiz': 15,
#  'wkly': 11,
#  'q': 6,
#  'top': 21,
#  'sony': 10,
#  'dvd': 8,
#  'player': 14,
#  'which': 51,
#  'country': 7,
#  'algarve': 2,
#  'ansr': 4,
#  '82277': 7,
#  'sp': 6,
#  'tyrone': 4,
#  'reached': 5,
#  'sch': 17,
#  'anytime': 13,
#  'mail': 24,
#  'miss': 59,
#  '8th': 6,
#  'fifty': 1,
#  '500': 35,
#  'msgs': 12,
#  '80488': 5,
#  'account': 32,
#  'fine': 42,
#  'safe': 9,
#  'wake': 21,
#  'long': 35,
#  'ago': 8,
#  'thing': 53,
#  'missionary': 1,
#  'hook': 4,
#  'doggy': 2,
#  'standing': 3,
#  'video': 27,
#  'network': 23,
#  'half': 30,
#  'line': 33,
#  'rental': 9,
#  'camcorder': 13,
#  '08000930705': 13,
#  'hate': 5,
#  'does': 26,
#  'turns': 5,
#  'shopping': 28,
#  'trip': 17,
#  'into': 31,
#  'annoying': 1,
#  'everything': 20,
#  'would': 68,
#  'very': 63,
#  'tired': 8,
#  'tomorro': 1,
#  'same': 42,
#  '2p': 2,
#  'per': 50,
#  'germany': 3,
#  '08448350055': 1,
#  'bt': 25,
#  'check': 29,
#  'planettalkinstant': 1,
#  'com': 57,
#  'info': 12,
#  'opt': 11,
#  'make': 85,
#  'alex': 7,
#  'knows': 8,
#  'birthday': 32,
#  'over': 53,
#  'fifteen': 4,
#  'minutes': 23,
#  'far': 15,
#  'concerned': 1,
#  'lag': 2,
#  'sad': 15,
#  'keep': 48,
#  'touch': 13,
#  'skype': 4,
#  'believe': 15,
#  'leh': 23,
#  'tot': 16,
#  'true': 24,
#  'muz': 10,
#  'tog': 3,
#  'before': 55,
#  'foreign': 2,
#  'stamps': 2,
#  'lecture': 4,
#  'pete': 6,
#  'meive': 1,
#  'hardly': 2,
#  'gotany': 1,
#  'jason': 3,
#  'says': 22,
#  'university': 2,
#  'southern': 1,
#  'california': 3,
#  'swimsuit': 1,
#  'allowed': 2,
#  'theatre': 4,
#  'wherever': 3,
#  'grand': 3,
#  'prix': 1,
#  'yourself': 18,
#  'tomo': 17,
#  'dating': 14,
#  'service': 51,
#  'has': 94,
#  'asked': 23,
#  'contact': 59,
#  'shy': 3,
#  '09058091870': 1,
#  'revealed': 5,
#  'pobox84': 5,
#  'm26': 3,
#  '3uz': 3,
#  'darlin': 11,
#  'youphone': 1,
#  'im': 62,
#  'athome': 1,
#  'youwanna': 1,
#  'yar': 11,
#  'else': 23,
#  'sorts': 1,
#  'funny': 6,
#  'things': 39,
#  'anyone': 15,
#  'spare': 2,
#  'off': 47,
#  'head': 14,
#  'faith': 2,
#  'makes': 14,
#  'hope': 83,
#  'beautiful': 17,
#  'christmas': 13,
#  'merry': 10,
#  'miles': 3,
#  'smiles': 3,
#  'made': 18,
#  'frm': 13,
#  'letters': 3,
#  'difference': 2,
#  'keeps': 2,
#  'though': 21,
#  'smiling': 15,
#  'nyt': 9,
#  'mum': 17,
#  'present': 6,
#  'ar': 6,
#  'saturday': 15,
#  'cherish': 2,
#  'brother': 18,
#  'role': 4,
#  'model': 4,
#  'hours': 19,
#  'called': 23,
#  'whole': 13,
#  'family': 15,
#  'cause': 13,
#  'started': 17,
#  'actor': 2,
#  'evening': 26,
#  'unemployed': 2,
#  'always': 41,
#  'wait': 58,
#  'bus': 23,
#  'aft': 13,
#  'lect': 7,
#  'lar': 33,
#  'needs': 13,
#  'dat': 31,
#  'slowly': 9,
#  'vomit': 5,
#  '1st': 31,
#  'no1': 5,
#  '8077': 2,
#  'txting': 8,
#  'mates': 13,
#  'getzed': 8,
#  '36504': 5,
#  'w45wq': 4,
#  '16': 39,
#  'norm150p': 4,
#  'sura': 5,
#  'sun': 15,
#  'tv': 27,
#  'tones': 20,
#  '4u': 7,
#  'rply': 11,
#  'title': 4,
#  'eg': 9,
#  'dracula': 2,
#  'titles': 3,
#  'ghost': 2,
#  'addamsfa': 2,
#  'munsters': 2,
#  'exorcist': 2,
#  'twilight': 2,
#  'pobox36504w45wq': 5,
#  'god': 39,
#  'bed': 27,
#  'erm': 3,
#  'woodland': 1,
#  'avenue': 1,
#  'somewhere': 7,
#  'parish': 1,
#  'magazine': 1,
#  'telephone': 2,
#  'completely': 7,
#  'form': 1,
#  'clark': 1,
#  'utter': 1,
#  'waste': 5,
#  'joined': 7,
#  'league': 1,
#  'people': 42,
#  'deal': 7,
#  'friend': 41,
#  'personal': 4,
#  'rayman': 1,
#  'golf': 1,
#  'post': 15,
#  'save': 8,
#  'activ8': 1,
#  'key': 4,
#  'termsapply': 1,
#  'cramps': 3,
#  'stopped': 4,
#  'lovely': 14,
#  'knowing': 2,
#  'morning': 61,
#  'write': 9,
#  'put': 26,
#  'dictionary': 3,
#  'mode': 6,
#  'cover': 7,
#  'screen': 2,
#  'hand': 9,
#  '5': 55,
#  'gently': 3,
#  'remove': 8,
#  'interesting': 4,
#  'jus': 26,
#  'fr': 11,
#  'lunch': 37,
#  'wif': 20,
#  'sis': 15,
#  'bank': 12,
#  'money': 42,
#  'hamster': 1,
#  'dead': 6,
#  'tmr': 24,
#  '1pm': 1,
#  'orchard': 9,
#  'mrt': 8,
#  'depends': 7,
#  'individual': 2,
#  'e': 76,
#  'dresser': 3,
#  'pretty': 12,
#  'gong': 1,
#  'kaypoh': 1,
#  'collecting': 2,
#  'attend': 3,
#  '2morro': 2,
#  'term': 4,
#  '2nite': 5,
#  'sexy': 22,
#  'passion': 1,
#  'b4': 10,
#  '09099726481': 1,
#  'luv': 27,
#  'dena': 1,
#  'calls': 20,
#  'minmobsmorelkpobox177hp51fl': 2,
#  'hows': 12,
#  'champ': 1,
#  'glasgow': 1,
#  'mmm': 4,
#  'yummy': 3,
#  'babe': 61,
#  'nice': 52,
#  'jolt': 1,
#  'suzy': 1,
#  'daily': 5,
#  'favour': 4,
#  'play': 28,
#  'driving': 16,
#  'clas': 1,
#  'newspapers': 1,
#  'most': 26,
#  ...}

# %%
m.inference('Hello, how are you')
# Out:
# 'ham'

# %%
m.inference('You won 10 free spins')
# Out:
# 'spam'

# %%
m.validation()
# Out:
# 'Validation accuracy: 0.92'

# %%
m.test()
# Out:
# 'Test accuracy: 0.89'
